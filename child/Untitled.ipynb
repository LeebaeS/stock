# %%
import pandas as pd

# %%
df = pd.read_csv('data/피해아동_특성_20250321164036.csv', encoding='cp949')

# %%
df
# Out:
#    피해아동 특성별(1) 피해아동 특성별(2)  2001  2002  2003  2004   2005   2006   2007  \
# 0            계          소계  2506  4568  5225  8651  10347  11075  12550
# 1           장애          소계    92   115   105   125    165    159    203
# 2           장애      신체적 장애     -     -     -     -      -      -      -
# 3           장애      정신적 장애     -     -     -     -      -      -      -
# 4           장애        장애의심     -     -     -     -      -      -      -
# ..         ...         ...   ...   ...   ...   ...    ...    ...    ...
# 61         전과력        보안처분     -     -     -     -      -      -      -
# 62         전과력        형사처벌     -     -     -     -      -      -      -
# 63        특성없음          소계     -     -     -     -      -      -      -
# 64          기타          소계   157   126   155   386    410    457    620
# 65        파악안됨          소계     0   221   234   257    319    471    487
#
#      2008   2009   2010   2011   2012   2013   2014   2015   2016   2017
# ...
